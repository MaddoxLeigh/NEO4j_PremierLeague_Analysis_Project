# %% [markdown]
# ## Purpose
# This script performs all of our webscrapping and saves the relevant data into json files. Lets explain the purpose of FBR and FBW:
# * FBRfExtractor(FBR): This class handles the extraction and scraping of data from FBRef. (the precise logic will be commented in the fbref.py file)
#
# * FBRefDataWriter (FBW): Following the data extraction from FBRef, we need to save this data, so this classhandles the writing of data to the write directories (within the data directory and the resepective season for the data we have extracted)
#
# Psuedo logic for code:
# 1. iterate over each specified season
# 2. extract all teams player in this season
# 3. extract all players, and their info, for all teams in this season
# 4. then get the fixtures for this league
# 5. if they've already occured, get all match logs (telling us about the performance for each player that featured in that game)

# %%
from utilities.fbref import FBRefExtractor, FBRefDataWriter
import os
import logging
logging.basicConfig(level=logging.INFO, format="%(message)s")

# first we need to locate the data directory, which is just a directory below our current working directory
data_directory = os.path.join(os.getcwd(),'data', "seasons")
# initialise both of these clases, note that FBW needs the data directory location to funtion
FBR = FBRefExtractor()
FBW = FBRefDataWriter(data_directory)

# declare the seasons that we wish to scrape for
premier_league_seasons = ["2021-2022", "2022-2023", "2023-2024", "2024-2025"]

# this dictionary is used as a cache for players when scraping multiple seasons. In a nutshell, after we scrape and extract data for a player from their page, 
# we store their details. So in the case when they appear across multiple seasons we don't need to rescrape their page, we can simply copy across their data
# from the other season they featured in . this helps reduce run time as MANY players appear in MANY seasons
all_players_dict = dict()

# now lets begin scraping for each season within the declared scope
for season in premier_league_seasons:

    # here we need to set the season for FBR to scrape.  THis is because we construct endpoints within the class and the endpoints are constructed differently
    # depending on if the season is the current season
    FBR.set_season(season)

    # initialise the dictionary for storing all players playing in THIS season
    # key: Player Name, value: Player Details
    season_all_players = dict()
    # this dictionary will store all players for each team in this season
    # key: Team Name, value: list of player names(str)
    team_players_dict = dict()

    # to extract team link, we first need to get the season endpoint of FBRef, so we construct it, and then parse it to extract_team_links to get a list of all team endpoints
    # FBR.extract_team_links returns a list of tuples of size 2(team_name, team_page (dependent on season) endpoint)
    team_links = FBR.extract_team_links(FBR.construct_season_endpoint())
    
    # we're using enumerate here so we can do logging.
    for team_count, team_data in enumerate(team_links.items()):
        
        logging.info(f"Processing team {team_count + 1}/{len(team_links)}: {team_name}")

        # unpack the tuple of data as described before
        team_name, team_link = team_data
        # create a list of players playing in the team, to be added as the value of key team in the team_players_dict
        team_players_list = list()

        # extract all player links from the teams page. This returns a dictionary
        # key: Player name, value: tuple of size 2: players name and their endpoint
        player_links = FBR.extract_player_links(team_link)

        # using enumerate here as well to do logging. We are now going to iterate over the dictionry
        for player_count,  player_data in enumerate(player_links.items()):
            
            logging.info(f"  Player {player_count + 1}/{len(player_links)}: {player_name}")
            
            player_name, player_endpoint = player_data #unpack data
            team_players_list.append(player_name) #add the players name to the team_players_list

            # if we've encountered this player previously in another season, just retrieve that player info and add it to the season players dict
            if player_name in all_players_dict:
                season_all_players[player_name] = all_players_dict[player_name]
            # if not, lets extract the details
            else:
                # FBR EXTRACT_PLAYER_details returns a dictionary of their details
                player_data = FBR.extract_player_details(player_endpoint)
                season_all_players[player_name] = player_data

        # after we've iteraeted over all players in a team, add the team players list to the dictionary
        team_players_dict[team_name] = team_players_list
        logging.info(f"Finished team: {team_name}")
    # after iterating over all teams, if we've encountered new players, add them to the cache for future usage
    all_players_dict = all_players_dict | season_all_players
    logging.info("All teams processed successfully.")

    # write this seasons player and team details to json files using FBW
    for data, filename in [(season_all_players, "players"),(team_players_dict, "teams")]:
        FBW.write_data(data, season, filename)
    logging.info("All seasons processed successfully. Saved to File.")
    
    # for this season extract the fixtures (match table). this returns some html. we need to first construct the fixtures endpoint
    fixtures = FBR.get_fixtures()
    # lets turn this html table in to a dictionary, and do some formatting
    fixtures_dict = FBR.fixtures_to_dict(fixtures)
    # for each match, if possible, add match data information. this is data about each players performance within that match
    fixtures_dict = FBR.append_match_data(fixtures_dict)

    # write all this data to a fixtures.json
    FBW.write_data(fixtures_dict,season, "fixtures")
# Out:
# 0
# Retrieved player data from fbref Alisson: {'position': 'GK', 'footed': 'Right', 'height': '193cm', 'weight': '91kg', 'dob': '1992-10-02', 'birth_place': 'Novo Hamburgo, Brazil', 'national_team': 'Brazilbr', 'club': 'Liverpool', 'wages': '￡ 150,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/7a2e46a8_2022.jpg'}
# 1
# Retrieved player data from fbref Virgil van Dijk: {'position': 'DF (CB, left)', 'footed': 'Right', 'height': '193cm', 'weight': '87kg', 'dob': '1991-07-08', 'birth_place': 'Breda, Netherlands', 'national_team': 'Netherlandsnl', 'club': 'Liverpool', 'wages': '￡ 220,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/e06683ca_2022.jpg'}
# 2
# Retrieved player data from fbref Trent Alexander-Arnold: {'position': 'DF (FB, right)', 'footed': 'Right', 'height': '175cm', 'weight': '68kg', 'dob': '1998-10-07', 'birth_place': 'Liverpool, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'wages': '￡ 180,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/cd1acf9d_2022.jpg'}
# 3
# Retrieved player data from fbref Sadio Mané: {'position': 'FW-MF (AM, left)', 'footed': 'Right', 'height': '175cm', 'weight': '68kg', 'dob': '1992-04-10', 'birth_place': 'Sédhiou, Senegal', 'national_team': 'Senegalsn', 'club': 'Al Nasr (KSA)', 'wages': '€ 423,077 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/c691bfe2_2022.jpg'}
# 4
# Retrieved player data from fbref Joël Matip: {'position': 'DF-MF (CB-DM, right)', 'footed': 'Right', 'height': '195cm', 'weight': '89kg', 'national_team': 'CamerooncmOther', 'img': 'https://fbref.com/req/202302030/images/headshots/b217ef29_2022.jpg'}
# 5
# Retrieved player data from fbref Mohamed Salah: {'position': 'FW-MF (AM-WM, right)', 'footed': 'Left', 'height': '175cm', 'weight': '71kg', 'dob': '1992-06-15', 'birth_place': 'Basyūn, Egypt', 'national_team': 'Egypteg', 'club': 'Liverpool', 'wages': '￡ 350,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/e342ad68_2022.jpg'}
# 6
# Retrieved player data from fbref Jordan Henderson: {'position': 'MF (CM-DM-WM, right)', 'footed': 'Right', 'height': '182cm', 'weight': '67kg', 'dob': '1990-06-17', 'birth_place': 'Sunderland, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Ajax', 'wages': '￡ 140,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/935e6b8f_2022.jpg'}
# 7
# Retrieved player data from fbref Andrew Robertson: {'position': 'DF-MF (FB, left)', 'footed': 'Left', 'height': '178cm', 'weight': '63kg', 'dob': '1994-03-11', 'birth_place': 'Glasgow, Scotland, United Kingdom', 'national_team': 'Scotlandsct', 'club': 'Liverpool', 'wages': '￡ 160,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/2e4f5f03_2022.jpg'}
# 8
# Retrieved player data from fbref Diogo Jota: {'position': 'FW-MF', 'footed': 'Right', 'height': '178cm', 'weight': '69kg', 'dob': '1996-12-04', 'birth_place': 'Massarelos, Portugal', 'national_team': 'Portugalpt', 'club': 'Liverpool', 'wages': '￡ 140,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/178ae8f8_2022.jpg'}
# 9
# Retrieved player data from fbref Fabinho: {'position': 'DF-MF (CM-DM-FB)', 'footed': 'Right', 'height': '188cm', 'weight': '78kg', 'dob': '1993-10-23', 'birth_place': 'Campinas, Brazil', 'national_team': 'Brazilbr', 'club': 'Al Ittihad Jeddah', 'wages': '￡ 180,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/7f3b388c_2022.jpg'}
# 10
# Retrieved player data from fbref Thiago Alcántara: {'position': 'MF (CM-DM-WM)', 'footed': 'Right', 'height': '172cm', 'weight': '59kg', 'national_team': 'SpainesOther', 'img': 'https://fbref.com/req/202302030/images/headshots/77e84962_2022.jpg'}
# 11
# Retrieved player data from fbref Naby Keïta: {'position': 'MF (AM-CM-WM)', 'footed': 'Right', 'height': '172cm', 'weight': '71kg', 'dob': '1995-02-10', 'birth_place': 'Conakry, Guinea', 'national_team': 'Guineagn', 'club': 'Ferencváros', 'wages': '€  Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/f25c8e3a_2022.jpg'}
# 12
# Retrieved player data from fbref Ibrahima Konaté: {'position': 'DF (CB, right)', 'footed': 'Right', 'height': '193cm', 'weight': '83kg', 'dob': '1999-05-25', 'birth_place': 'Paris, France', 'national_team': 'Francefr', 'club': 'Liverpool', 'wages': '￡ 70,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/5ed9b537_2022.jpg'}
# 13
# Retrieved player data from fbref Luis Díaz: {'position': 'FW-MF (AM-WM, left)', 'footed': 'Right', 'height': '180cm', 'weight': '72kg', 'dob': '1997-01-13', 'birth_place': 'Barrancas, Colombia', 'national_team': 'Colombiaco', 'club': 'Liverpool', 'wages': '￡ 55,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/4a1a9578_2022.jpg'}
# 14
# Retrieved player data from fbref Roberto Firmino: {'position': 'FW-MF (AM)', 'footed': 'Right', 'height': '181cm', 'weight': '76kg', 'dob': '1991-10-02', 'birth_place': 'Maceió, Brazil', 'national_team': 'Brazilbr', 'club': 'Al-Ahli', 'img': 'https://fbref.com/req/202302030/images/headshots/4c370d81_2022.jpg'}
# 15
# Retrieved player data from fbref Curtis Jones: {'position': 'FW-MF (CM-WM)', 'footed': 'Right', 'height': '185cm', 'weight': '72kg', 'dob': '2001-01-30', 'birth_place': 'Liverpool, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'wages': '￡ 15,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/4fb9c88f_2022.jpg'}
# 16
# Retrieved player data from fbref Kostas Tsimikas: {'position': 'DF (FB, left)', 'footed': 'Left', 'height': '177cm', 'weight': '69kg', 'dob': '1996-05-12', 'birth_place': 'Dimos Thessaloniki, Greece', 'national_team': 'Greecegr', 'club': 'Liverpool', 'wages': '￡ 75,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/f315ca93_2022.jpg'}
# 17
# Retrieved player data from fbref James Milner: {'position': 'DF-MF (CM-FB-WM)', 'footed': 'Right', 'height': '176cm', 'weight': '69kg', 'dob': '1986-01-04', 'birth_place': 'Leeds, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Brighton & Hove Albion', 'wages': '￡ 60,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/2f90f6b8_2022.jpg'}
# 18
# Retrieved player data from fbref Alex Oxlade-Chamberlain: {'position': 'FW-MF (AM-CM-WM)', 'footed': 'Right', 'height': '180cm', 'weight': '74kg', 'dob': '1993-08-15', 'birth_place': 'Portsmouth, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Beşiktaş', 'img': 'https://fbref.com/req/202302030/images/headshots/38c7feef_2022.jpg'}
# 19
# Retrieved player data from fbref Harvey Elliott: {'position': 'FW-MF (WM, right)', 'footed': 'Left', 'height': '170cm', 'weight': '67kg', 'dob': '2003-04-04', 'birth_place': 'Chertsey, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'wages': '￡ 40,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/c8387671_2022.jpg'}
# 20
# Retrieved player data from fbref Joe Gomez: {'position': 'DF (CB-FB, right)', 'footed': 'Right', 'height': '188cm', 'weight': '77kg', 'dob': '1997-05-23', 'birth_place': 'Catford, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'wages': '￡ 85,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/7a11550b_2022.jpg'}
# 21
# Retrieved player data from fbref Caoimhín Kelleher: {'position': 'GK', 'footed': 'Right', 'height': '188cm', 'weight': '81kg', 'dob': '1998-11-23', 'birth_place': 'Cork, Republic of Ireland', 'national_team': 'Republic of Irelandie', 'club': 'Liverpool', 'wages': '￡ 10,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/62d7ef38_2022.jpg'}
# 22
# Retrieved player data from fbref Takumi Minamino: {'position': 'FW-MF (AM)', 'footed': 'Right', 'height': '174cm', 'weight': '67kg', 'dob': '1995-01-16', 'birth_place': 'Izumisano Shi, Japan', 'national_team': 'Japanjp', 'club': 'Monaco', 'wages': '€ 88,462 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/f833a830_2022.jpg'}
# 23
# Retrieved player data from fbref Tyler Morton: {'position': 'MF (CM-DM)', 'footed': 'Right', 'height': '178cm', 'weight': '67kg', 'dob': '2002-10-31', 'birth_place': 'England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'img': 'https://fbref.com/req/202302030/images/headshots/2bc28bb9_2022.jpg'}
# 24
# Retrieved player data from fbref Divock Origi: {'position': 'FW-MF (WM)', 'footed': 'Right', 'height': '186cm', 'weight': '74kg', 'dob': '1995-04-18', 'birth_place': 'Ostend, Belgium', 'national_team': 'Belgiumbe', 'club': 'Milan', 'wages': '€ 98,654 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/43a166b4_2022.jpg'}
# 25
# Retrieved player data from fbref Kaide Gordon: {'position': 'FW', 'footed': 'Left', 'height': '179cm', 'weight': '63kg', 'dob': '2004-10-05', 'birth_place': 'England, United Kingdom', 'img': 'https://fbref.com/req/202302030/images/headshots/19a9cb70_2022.jpg'}
# 26
# Retrieved player data from fbref Neco Williams: {'position': 'DF-MF (FB, right)', 'footed': 'Right', 'height': '183cm', 'weight': '76kg', 'dob': '2001-04-13', 'birth_place': 'Wrexham, Wales, United Kingdom', 'national_team': 'Waleswls', 'club': 'Nottingham Forest', 'wages': '￡ 50,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/dd323728_2022.jpg'}
# 27
# Retrieved player data from fbref Adrián: {'position': 'GK', 'footed': 'Right', 'height': '190cm', 'weight': '83kg', 'dob': '1987-01-03', 'birth_place': 'Sevilla, Spain', 'club': 'Real Betis', 'wages': '€ 16,154 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/f76e6b4e_2022.jpg'}
# 28
# Retrieved player data from fbref Owen Beck: {'position': 'DF (FB, left)', 'height': '177cm', 'weight': '58kg', 'dob': '2002-08-09', 'birth_place': 'Wales, England, United Kingdom', 'national_team': 'Waleswls', 'club': 'Blackburn Rovers', 'img': 'https://fbref.com/req/202302030/images/headshots/a011a1e9_2022.jpg'}
# 29
# Retrieved player data from fbref Conor Bradley: {'position': 'DF-MF (FB, right)', 'footed': 'Right', 'height': '181cm', 'weight': '68kg', 'dob': '2003-07-09', 'birth_place': 'Northern Ireland, United Kingdom', 'national_team': 'Northern Irelandnir', 'club': 'Liverpool', 'wages': '￡ 10,000 Weekly', 'contract_expiry': 'June 2027', 'img': 'https://fbref.com/req/202302030/images/headshots/bbd67769_2022.jpg'}
# 30
# Retrieved player data from fbref Nathaniel Phillips: {'position': 'DF (CB, right)', 'footed': 'Right', 'height': '190cm', 'weight': '83kg', 'dob': '1997-03-21', 'birth_place': 'England, United Kingdom', 'club': 'Derby County', 'wages': '￡ 65,000 Weekly', 'contract_expiry': 'June 2025', 'img': 'https://fbref.com/req/202302030/images/headshots/515ebe8d_2022.jpg'}
# 31
# Retrieved player data from fbref Marcelo Pitaluga: {'position': 'GK', 'height': '192cm', 'weight': '78kg', 'dob': '2002-12-20', 'birth_place': 'Niterói, Brazil', 'club': 'Fluminense', 'img': 'https://fbref.com/req/202302030/images/headshots/b3cafda8_2022.jpg'}
# 32
# Retrieved player data from fbref Jarell Quansah: {'position': 'DF (CB)', 'height': '197cm', 'weight': '79kg', 'dob': '2003-01-29', 'birth_place': 'Warrington, England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Liverpool', 'img': 'https://fbref.com/req/202302030/images/headshots/4125cb98_2022.jpg'}
# 33
# Retrieved player data from fbref Rhys Williams: {'position': 'DF (CB)', 'footed': 'Right', 'height': '188cm', 'weight': '73kg', 'dob': '2001-02-03', 'birth_place': 'England, United Kingdom', 'national_team': 'Englandeng', 'club': 'Morecambe', 'wages': '￡ 10,000 Weekly', 'contract_expiry': 'June 2026', 'img': 'https://fbref.com/req/202302030/images/headshots/012c975a_2022.jpg'}
# 34
# Retrieved player data from fbref Ben Woodburn: {'position': 'FW-MF', 'footed': 'Right', 'height': '174cm', 'weight': '72kg', 'dob': '1999-10-15', 'birth_place': 'County of Cheshire, England, United Kingdom', 'national_team': 'WaleswlsOther', 'club': 'Salford City FC', 'img': 'https://fbref.com/req/202302030/images/headshots/8aadeaef_2022.jpg'}
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/78/b2j3spl172n6y7p_sw2jggr40000gn/T/ipykernel_68041/3230966816.py in <module>
#      49     fixtures = FBR.get_fixtures(FBR.construct_season_endpoint(id="fixtures"))
#      50     fixtures_dict = FBR.fixtures_to_dict(fixtures)
# ---> 51     fixtures_dict = FBR.append_match_data(fixtures_dict)
#      52
#      53     FBW.write_data(fixtures_dict,season, "fixtures_x")
#
# ~/Coding/GitHub/project-at2024-dam/utilities/fbref.py in append_match_data(self, fixtures_dict)
#     240         for count, match in enumerate(fixtures_dict):
#     241             if match["Match_Report"]:
# --> 242                 home_player_stats, away_player_stats, home_goalie_stats, away_goalie_stats = self.get_match_data(match["Match Report Link"])
#     243                 match["Home_Player_Stats"] = home_player_stats
#     244                 match["Away_Player_Stats"] = away_player_stats
#
# ValueError: not enough values to unpack (expected 4, got 0)
