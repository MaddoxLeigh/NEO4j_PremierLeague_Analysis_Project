# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pickle
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable
import logging
import pandas as pd
# Out:
# /Users/dylan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dylan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
fbref_url = "https://fbref.com{}"
premier_league = fbref_url.format("/en/comps/9/Premier-League-Stats")
data = requests.get(premier_league)

# %% [markdown]
# # CHANGE DETAILS BELOW FOR PERSONAL INSTANCE WHEN RUNNING

# %%
# dylan instance details 
NEO4J_URI='neo4j+s://2b521897.databases.neo4j.io'
NEO4J_USERNAME='neo4j'
NEO4J_PASSWORD='nCUihZktDGHjJUpQtKUal0IJhrk0eSuMdSFUm99Th3Q'
AURA_INSTANCEID='2b521897'
AURA_INSTANCENAME='Instance01'

# %%
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
with open(f'team_dict_24-25.pkl', 'rb') as f:
        team_dict = pickle.load(f)

# %%
team_players = dict()
player_details = list()
for team, players in team_dict.items():
    team_players[team] = list()
    for player in players.keys():
        team_players[team].append(player)
        players[player]['Name'] = player
        player_details.append(players[player])

# %%
# clean up before sending
with open('match_reports.pkl','rb') as f:
    match_reports = pickle.load(f)

# %%
fixtures_df = pd.read_csv('fixtures.csv')
fixtures_df[['Home_Score', 'Away_Score']] = fixtures_df['Score'].str.split('–', expand=True)

# %%
all_players_dict = pd.read_csv('all_players.csv', index_col=0).to_dict(orient='index')

# %%
# this is very important please do not delete
mappings = {"Brighton":'Brighton & Hove Albion',
            'Manchester Utd':'Manchester United',
            'Newcastle Utd':'Newcastle United',
            "Nott'ham Forest":'Nottingham Forest',
            'Tottenham':'Tottenham Hotspur',
            'West Ham':'West Ham United',
            'Wolves':'Wolverhampton Wanderers'}

# %%
# fixtures_df['Home'] = fixtures_df['Home'].map(mappings)
# fixtures_df['Away'] = fixtures_df['Away'].map(mappings)
fixtures_df['Home'] = fixtures_df['Home'].apply(lambda x: mappings[x] if x in mappings else x)
fixtures_df['Away'] = fixtures_df['Away'].apply(lambda x: mappings[x] if x in mappings else x)

# %%
with driver.session(database="neo4j") as session:
    query = "match (n) detach delete n"
    session.run(query)

# %%
with driver.session(database="neo4j") as session:
    query = "CREATE (l:League {name: $name})"
    session.run(query, {"name":"PremierLeague"})

    query = "CREATE (s:Season {name: $name})"
    session.run(query, {"name":"24-25"})

    query = """
        MATCH (s:Season{name:$season_name}), (l:League{name: $league_name}) 
        CREATE (s)-[:SEASON_OF_LEAGUE]->(l)
        """
    print(session.run(query, {"league_name": "PremierLeague", "season_name": "24-25"}))
# Out:
# <neo4j._sync.work.result.Result object at 0x7fc7f961bb20>

# %%
team_players = dict()
player_details = list()

for team, players in team_dict.items():
    team_players[team] = list()
    for player in players.keys():
        team_players[team].append(player)
        players[player]['Name'] = player
        players[player]['Team'] = team  # Fix the key access from player to players
        player_details.append(players[player])
    team_players[team] = team_players[team]

with driver.session(database="neo4j") as session:
    query = """
            UNWIND $players AS player
            MERGE (p:Player {name: player.Name})
            SET p.position = player.position,
                p.footed = player.footed,
                p.height = player.height,
                p.weight = player.weight,
                p.dob = player.dob,
                p.birth_place = player.birth_place,
                p.national_team = player.national_team,
                p.club = player.club,
                p.wages = player.wages,
                p.contract_expiry = player.contract_expiry,
                p.img = player.img

            MERGE (team:Team {name: player.Team})
            MERGE (p)-[:PLAYS_FOR]->(team)
    """
    
    session.run(query, players=player_details)

# %%
with driver.session(database="neo4j") as session:
    # Create GameWeek nodes and relationships
    for gw in range(1, 39):  # Loop from 1 to 38
        query = """
        MATCH (s:Season {name: $season_name})
        CREATE (gw:GameWeek {number: $number})-[:IS_A_GW]->(s)
        """
        session.run(query, {"season_name": "24-25", "number": f"GW{gw}"})

# %%
fixtures_df[fixtures_df["Match Report"] == "Match Report"]
# Out:
#      Unnamed: 0    GW  Day        Date   Time             Home   xG Score  \
# 0             0   GW1  Fri  2024-08-16  20:00   Manchester Utd  2.4   1–0
# 1             1   GW1  Sat  2024-08-17  12:30     Ipswich Town  0.5   0–2
# 2             2   GW1  Sat  2024-08-17  15:00    Newcastle Utd  0.3   1–0
# 3             3   GW1  Sat  2024-08-17  15:00  Nott'ham Forest  1.3   1–1
# 4             4   GW1  Sat  2024-08-17  15:00          Everton  0.5   0–3
# ..          ...   ...  ...         ...    ...              ...  ...   ...
# 202         222  GW21  Tue  2025-01-14  20:00  Nott'ham Forest  0.3   1–1
# 203         223  GW21  Wed  2025-01-15  19:30          Everton  1.1   0–1
# 204         224  GW21  Wed  2025-01-15  19:30    Newcastle Utd  1.9   3–0
# 205         225  GW21  Wed  2025-01-15  19:30   Leicester City  1.5   0–2
# 206         226  GW21  Wed  2025-01-15  20:00          Arsenal  1.4   2–1
#
#      xG.1            Away  Attendance                 Venue         Referee  \
# 0     0.4          Fulham     73297.0          Old Trafford    Robert Jones
# 1     2.6       Liverpool     30014.0  Portman Road Stadium    Tim Robinson
# 2     1.8     Southampton     52196.0        St James' Park    Craig Pawson
# 3     1.2     Bournemouth     29763.0       The City Ground  Michael Oliver
# 4     1.4        Brighton     39217.0         Goodison Park    Simon Hooper
# ..    ...             ...         ...                   ...             ...
# 202   2.0       Liverpool     30249.0       The City Ground  Chris Kavanagh
# 203   1.4     Aston Villa     39085.0         Goodison Park  Samuel Barrott
# 204   1.4          Wolves     51975.0        St James' Park  Darren England
# 205   1.8  Crystal Palace     29766.0    King Power Stadium     Andy Madley
# 206   0.8       Tottenham     60287.0      Emirates Stadium    Simon Hooper
#
#      Match Report  Notes Home_Score Away_Score
# 0    Match Report    NaN          1          0
# 1    Match Report    NaN          0          2
# 2    Match Report    NaN          1          0
# 3    Match Report    NaN          1          1
# 4    Match Report    NaN          0          3
# ..            ...    ...        ...        ...
# 202  Match Report    NaN          1          1
# 203  Match Report    NaN          0          1
# 204  Match Report    NaN          3          0
# 205  Match Report    NaN          0          2
# 206  Match Report    NaN          2          1
#
# [207 rows x 17 columns]

# %%
with driver.session(database="neo4j") as session:
    for _, row in fixtures_df.iterrows():
        query = """
        MERGE (venue:Venue {name: $venue})
        
        MERGE (home_team:Team {name: $home_team})
        MERGE (away_team:Team {name: $away_team})
        
        MERGE (gameweek:GameWeek {number: $gameweek})
        
        MERGE (match)-[:PLAYED_AT]->(venue)
        MERGE (match)-[:HOME_TEAM]->(home_team)
        MERGE (match)-[:AWAY_TEAM]->(away_team)
        MERGE (match)-[:PART_OF]->(gameweek)
        """    
        query_set = """
        MERGE (match:Match {id: $match_id})
        SET match.date = $date,
            match.time = $time,
            match.home_team = $home_team,
            match.away_team = $away_team
        """
        print(row["Venue"])
        data = {
            "match_id": f"{row['GW']}_{row['Home']}_vs_{row['Away']}",
            "date": row["Date"],
            "time": row["Time"],
            "home_team": row["Home"],
            "away_team": row["Away"],
            "gameweek": row["GW"],
            "venue": row["Venue"]
        }
        # if the match has occured
        if row["Match Report"] == "Match Report":
            data.update({
                "home_expected": row["xG"],
                "away_expected": row["xG.1"],
                "home_score": row["Home_Score"],
                "away_score": row["Away_Score"],
                "referee": row["Referee"]
            })
            query_set += """
            ,match.home_score = $home_score,
            match.away_score = $away_score,
            match.home_expected = $home_expected,
            match.away_expected = $away_expected,
            match.referee = $referee
            MERGE (ref:Referee {name: $referee})
            MERGE (match)-[:REFERRED_BY]->(ref)
            """
        session.run(query_set+query, data)
# Out:
# Old Trafford
# Portman Road Stadium
# St James' Park
# The City Ground
# Goodison Park
# Emirates Stadium
# London Stadium
# Gtech Community Stadium
# Stamford Bridge
# King Power Stadium
# The American Express Stadium
# Tottenham Hotspur Stadium
# Craven Cottage
# Selhurst Park
# Etihad Stadium
# St Mary's Stadium
# Villa Park
# Vitality Stadium
# Molineux Stadium
# Anfield
# Emirates Stadium
# Goodison Park
# King Power Stadium
# The City Ground
# Portman Road Stadium
# Gtech Community Stadium
# London Stadium
# St James' Park
# Stamford Bridge
# Old Trafford
# St Mary's Stadium
# The American Express Stadium
# Selhurst Park
# Etihad Stadium
# Anfield
# Craven Cottage
# Villa Park
# Vitality Stadium
# Tottenham Hotspur Stadium
# Molineux Stadium
# London Stadium
# Anfield
# King Power Stadium
# St Mary's Stadium
# Tottenham Hotspur Stadium
# Craven Cottage
# Villa Park
# Selhurst Park
# The American Express Stadium
# Etihad Stadium
# St James' Park
# Stamford Bridge
# Emirates Stadium
# Gtech Community Stadium
# Goodison Park
# The City Ground
# Molineux Stadium
# Portman Road Stadium
# Old Trafford
# Vitality Stadium
# Selhurst Park
# Etihad Stadium
# Gtech Community Stadium
# London Stadium
# Emirates Stadium
# King Power Stadium
# Goodison Park
# Villa Park
# Stamford Bridge
# The American Express Stadium
# Tottenham Hotspur Stadium
# St Mary's Stadium
# Portman Road Stadium
# St James' Park
# Craven Cottage
# Old Trafford
# Vitality Stadium
# Molineux Stadium
# Anfield
# The City Ground
# King Power Stadium
# Gtech Community Stadium
# The American Express Stadium
# Etihad Stadium
# Villa Park
# Goodison Park
# Stamford Bridge
# London Stadium
# Selhurst Park
# Emirates Stadium
# St James' Park
# St Mary's Stadium
# Anfield
# The City Ground
# Portman Road Stadium
# Vitality Stadium
# Molineux Stadium
# Tottenham Hotspur Stadium
# Old Trafford
# Craven Cottage
# Gtech Community Stadium
# London Stadium
# Selhurst Park
# Molineux Stadium
# The American Express Stadium
# Anfield
# Old Trafford
# The City Ground
# Tottenham Hotspur Stadium
# Stamford Bridge
# King Power Stadium
# Emirates Stadium
# Vitality Stadium
# Villa Park
# Goodison Park
# Craven Cottage
# Etihad Stadium
# St Mary's Stadium
# Portman Road Stadium
# St James' Park
# The American Express Stadium
# Selhurst Park
# Molineux Stadium
# The City Ground
# Gtech Community Stadium
# London Stadium
# Stamford Bridge
# Tottenham Hotspur Stadium
# Old Trafford
# Anfield
# Portman Road Stadium
# King Power Stadium
# Goodison Park
# St James' Park
# Etihad Stadium
# St Mary's Stadium
# Emirates Stadium
# Villa Park
# Craven Cottage
# Vitality Stadium
# Gtech Community Stadium
# Selhurst Park
# Villa Park
# Old Trafford
# Craven Cottage
# Portman Road Stadium
# King Power Stadium
# Tottenham Hotspur Stadium
# London Stadium
# St James' Park
# Emirates Stadium
# Molineux Stadium
# Anfield
# The City Ground
# The American Express Stadium
# Etihad Stadium
# St Mary's Stadium
# Stamford Bridge
# Vitality Stadium
# Villa Park
# London Stadium
# Gtech Community Stadium
# Portman Road Stadium
# Selhurst Park
# Old Trafford
# Craven Cottage
# Goodison Park
# King Power Stadium
# Tottenham Hotspur Stadium
# Etihad Stadium
# Stamford Bridge
# St Mary's Stadium
# Vitality Stadium
# St James' Park
# The City Ground
# Molineux Stadium
# Anfield
# The American Express Stadium
# Emirates Stadium
# King Power Stadium
# Tottenham Hotspur Stadium
# Craven Cottage
# Goodison Park
# Selhurst Park
# London Stadium
# Villa Park
# Portman Road Stadium
# Old Trafford
# Gtech Community Stadium
# Tottenham Hotspur Stadium
# St Mary's Stadium
# Vitality Stadium
# Selhurst Park
# Etihad Stadium
# Villa Park
# The American Express Stadium
# Craven Cottage
# Anfield
# Molineux Stadium
# Gtech Community Stadium
# London Stadium
# Stamford Bridge
# The City Ground
# Goodison Park
# St James' Park
# King Power Stadium
# Emirates Stadium
# Portman Road Stadium
# Old Trafford
# St James' Park
# London Stadium
# Gtech Community Stadium
# King Power Stadium
# Emirates Stadium
# Old Trafford
# The City Ground
# Goodison Park
# Portman Road Stadium
# Stamford Bridge
# Molineux Stadium
# St Mary's Stadium
# The American Express Stadium
# Anfield
# Vitality Stadium
# Etihad Stadium
# Selhurst Park
# Tottenham Hotspur Stadium
# Villa Park
# Craven Cottage
# The City Ground
# Portman Road Stadium
# Goodison Park
# St James' Park
# Vitality Stadium
# Molineux Stadium
# Gtech Community Stadium
# Old Trafford
# Emirates Stadium
# Stamford Bridge
# Goodison Park
# The American Express Stadium
# King Power Stadium
# Villa Park
# Craven Cottage
# London Stadium
# Etihad Stadium
# St Mary's Stadium
# Selhurst Park
# Anfield
# Tottenham Hotspur Stadium
# King Power Stadium
# Goodison Park
# Craven Cottage
# Portman Road Stadium
# Vitality Stadium
# Emirates Stadium
# St Mary's Stadium
# Villa Park
# St James' Park
# Etihad Stadium
# London Stadium
# Gtech Community Stadium
# Tottenham Hotspur Stadium
# Molineux Stadium
# The City Ground
# The American Express Stadium
# Selhurst Park
# Stamford Bridge
# Anfield
# Old Trafford
# Anfield
# Stamford Bridge
# Molineux Stadium
# London Stadium
# Tottenham Hotspur Stadium
# Old Trafford
# Selhurst Park
# The City Ground
# The American Express Stadium
# Gtech Community Stadium
# Emirates Stadium
# Villa Park
# Craven Cottage
# St James' Park
# King Power Stadium
# Etihad Stadium
# Portman Road Stadium
# Goodison Park
# St Mary's Stadium
# Vitality Stadium
# The American Express Stadium
# Vitality Stadium
# Molineux Stadium
# Emirates Stadium
# The City Ground
# St Mary's Stadium
# Stamford Bridge
# Etihad Stadium
# St James' Park
# Anfield
# London Stadium
# Old Trafford
# Gtech Community Stadium
# Villa Park
# Goodison Park
# Craven Cottage
# Portman Road Stadium
# King Power Stadium
# Selhurst Park
# Tottenham Hotspur Stadium
# Vitality Stadium
# St James' Park
# Emirates Stadium
# Anfield
# Molineux Stadium
# The American Express Stadium
# Etihad Stadium
# The City Ground
# Stamford Bridge
# St Mary's Stadium
# King Power Stadium
# Portman Road Stadium
# Gtech Community Stadium
# Villa Park
# Tottenham Hotspur Stadium
# London Stadium
# Selhurst Park
# Goodison Park
# Craven Cottage
# Old Trafford
# Stamford Bridge
# Molineux Stadium
# St James' Park
# Etihad Stadium
# Anfield
# Emirates Stadium
# Vitality Stadium
# St Mary's Stadium
# The City Ground
# The American Express Stadium
# Stamford Bridge
# Gtech Community Stadium
# Etihad Stadium
# London Stadium
# Selhurst Park
# Emirates Stadium
# Goodison Park
# Villa Park
# The American Express Stadium
# King Power Stadium
# Anfield
# St Mary's Stadium
# Tottenham Hotspur Stadium
# Craven Cottage
# St James' Park
# The City Ground
# Old Trafford
# Vitality Stadium
# Portman Road Stadium
# Molineux Stadium
# Gtech Community Stadium
# Emirates Stadium
# The American Express Stadium
# King Power Stadium
# London Stadium
# Goodison Park
# Villa Park
# Stamford Bridge
# Etihad Stadium
# Selhurst Park
# St Mary's Stadium
# Anfield
# Portman Road Stadium
# Vitality Stadium
# St James' Park
# Craven Cottage
# The City Ground
# Old Trafford
# Molineux Stadium
# Tottenham Hotspur Stadium

# %%
with driver.session(database="neo4j") as session:
    for i, row in fixtures_df[:len(match_reports)].iterrows():
        match_id = f"{row['GW']}_{row['Home']}_vs_{row['Away']}"


        home_team_stats = match_reports[i][0][0][:-1] 
        away_team_stats = match_reports[i][1][0][:-1] 
        home_team_goaly_stats = match_reports[i][0][1] 
        away_team_goaly_stats = match_reports[i][1][1]

        home_team_name = row['Home']
        away_team_name = row['Away']


        # Add Home Team Player Stats
        for _, player_stats in home_team_stats.iterrows():
            player_query = """
            MERGE (player:Player {name: $player_name})
            MERGE (team:Team {name: $team_name})
            MERGE (player)-[:PLAYS_FOR]->(team)
            MERGE (match:Match {id: $match_id})
            MERGE (match)-[h:HOME_TEAM_PLAYER_STATS]->(player)
            SET h.goals = $goals,
                h.assists = $assists,
                h.penalties = $penalties,
                h.shots = $shots,
                h.shots_on_target = $shots_on_target,
                h.touches = $touches,
                h.tackles = $tackles,
                h.interceptions = $interceptions,
                h.blocks = $blocks,
                h.xg = $xg,
                h.npxg = $npxg,
                h.xag = $xag,
                h.sca = $sca,
                h.gca = $gca,
                h.passes_completed = $passes_completed,
                h.passes_attempted = $passes_attempted,
                h.pass_accuracy = $pass_accuracy,
                h.progressive_passes = $progressive_passes,
                h.carries = $carries,
                h.progressive_carries = $progressive_carries
            """
            session.run(player_query, {
                "player_name": player_stats[('Unnamed: 0_level_0', 'Player')],
                "nation": player_stats[('Unnamed: 2_level_0', 'Nation')],
                "position": player_stats[('Unnamed: 3_level_0', 'Pos')],
                "age": player_stats[('Unnamed: 4_level_0', 'Age')],
                "match_id": match_id,
                "team_name": home_team_name,
                "goals": player_stats[('Performance', 'Gls')],
                "assists": player_stats[('Performance', 'Ast')],
                "penalties": player_stats[('Performance', 'PK')],
                "shots": player_stats[('Performance', 'Sh')],
                "shots_on_target": player_stats[('Performance', 'SoT')],
                "touches": player_stats[('Performance', 'Touches')],
                "tackles": player_stats[('Performance', 'Tkl')],
                "interceptions": player_stats[('Performance', 'Int')],
                "blocks": player_stats[('Performance', 'Blocks')],
                "xg": player_stats[('Expected', 'xG')],
                "npxg": player_stats[('Expected', 'npxG')],
                "xag": player_stats[('Expected', 'xAG')],
                "sca": player_stats[('SCA', 'SCA')],
                "gca": player_stats[('SCA', 'GCA')],
                "passes_completed": player_stats[('Passes', 'Cmp')],
                "passes_attempted": player_stats[('Passes', 'Att')],
                "pass_accuracy": player_stats[('Passes', 'Cmp%')],
                "progressive_passes": player_stats[('Passes', 'PrgP')],
                "carries": player_stats[('Carries', 'Carries')],
                "progressive_carries": player_stats[('Carries', 'PrgC')],
            })

        # Add Away Team Player Stats
        for _, player_stats in away_team_stats.iterrows():
            player_query = """
            MERGE (player:Player {name: $player_name})
            MERGE (team:Team {name: $team_name})
            MERGE (player)-[:PLAYS_FOR]->(team)
            MERGE (match:Match {id: $match_id})
            MERGE (match)-[a:AWAY_TEAM_PLAYER_STATS]->(player)
            SET a.goals = $goals,
                a.assists = $assists,
                a.penalties = $penalties,
                a.shots = $shots,
                a.shots_on_target = $shots_on_target,
                a.touches = $touches,
                a.tackles = $tackles,
                a.interceptions = $interceptions,
                a.blocks = $blocks,
                a.xg = $xg,
                a.npxg = $npxg,
                a.xag = $xag,
                a.sca = $sca,
                a.gca = $gca,
                a.passes_completed = $passes_completed,
                a.passes_attempted = $passes_attempted,
                a.pass_accuracy = $pass_accuracy,
                a.progressive_passes = $progressive_passes,
                a.carries = $carries,
                a.progressive_carries = $progressive_carries
            """
            session.run(player_query, {
                "player_name": player_stats[('Unnamed: 0_level_0', 'Player')],
                "nation": player_stats[('Unnamed: 2_level_0', 'Nation')],
                "position": player_stats[('Unnamed: 3_level_0', 'Pos')],
                "age": player_stats[('Unnamed: 4_level_0', 'Age')],
                "match_id": match_id,
                "team_name": away_team_name,
                "goals": player_stats[('Performance', 'Gls')],
                "assists": player_stats[('Performance', 'Ast')],
                "penalties": player_stats[('Performance', 'PK')],
                "shots": player_stats[('Performance', 'Sh')],
                "shots_on_target": player_stats[('Performance', 'SoT')],
                "touches": player_stats[('Performance', 'Touches')],
                "tackles": player_stats[('Performance', 'Tkl')],
                "interceptions": player_stats[('Performance', 'Int')],
                "blocks": player_stats[('Performance', 'Blocks')],
                "xg": player_stats[('Expected', 'xG')],
                "npxg": player_stats[('Expected', 'npxG')],
                "xag": player_stats[('Expected', 'xAG')],
                "sca": player_stats[('SCA', 'SCA')],
                "gca": player_stats[('SCA', 'GCA')],
                "passes_completed": player_stats[('Passes', 'Cmp')],
                "passes_attempted": player_stats[('Passes', 'Att')],
                "pass_accuracy": player_stats[('Passes', 'Cmp%')],
                "progressive_passes": player_stats[('Passes', 'PrgP')],
                "carries": player_stats[('Carries', 'Carries')],
                "progressive_carries": player_stats[('Carries', 'PrgC')],
            })

         # Add Home Team Goalie Stats
        goalie_query = """
            MERGE (goalie:Player {name: $goalie_name})
            MERGE (team:Team {name: $team_name})
            MERGE (goalie)-[:PLAYS_FOR]->(team)
            MERGE (match:Match {id: $match_id})
            MERGE (match)-[:HOME_TEAM_GOALIE_STATS]->(goalie)
            SET goalie.minutes_played = $minutes_played,
                goalie.sota = $sota,
                goalie.goals_allowed = $goals_allowed,
                goalie.saves = $saves,
                goalie.save_percentage = $save_percentage,
                goalie.psxg = $psxg,
                goalie.passes_completed = $passes_completed,
                goalie.passes_attempted = $passes_attempted,
                goalie.pass_accuracy = $pass_accuracy,
                goalie.gk_passes_attempted = $gk_passes_attempted,
                goalie.throws = $throws,
                goalie.launch_percentage = $launch_percentage,
                goalie.launch_average_length = $launch_average_length,
                goalie.goal_kicks_attempted = $goal_kicks_attempted,
                goalie.goal_kick_launch_percentage = $goal_kick_launch_percentage,
                goalie.goal_kick_average_length = $goal_kick_average_length,
                goalie.crosses_opportunities = $crosses_opportunities,
                goalie.crosses_stops = $crosses_stops,
                goalie.crosses_stop_percentage = $crosses_stop_percentage,
                goalie.opa = $opa,
                goalie.opa_average_distance = $opa_average_distance
            """
        
        for _, goalie_stats in home_team_goaly_stats.iterrows():

            session.run(goalie_query, {
                "goalie_name": goalie_stats[('Unnamed: 0_level_0', 'Player')],
                "nation": goalie_stats[('Unnamed: 1_level_0', 'Nation')],
                "age": goalie_stats[('Unnamed: 2_level_0', 'Age')],
                "match_id": match_id,
                "team_name": home_team_name,
                "minutes_played": goalie_stats[('Unnamed: 3_level_0', 'Min')],
                "sota": goalie_stats[('Shot Stopping', 'SoTA')],
                "goals_allowed": goalie_stats[('Shot Stopping', 'GA')],
                "saves": goalie_stats[('Shot Stopping', 'Saves')],
                "save_percentage": goalie_stats[('Shot Stopping', 'Save%')],
                "psxg": goalie_stats[('Shot Stopping', 'PSxG')],
                "passes_completed": goalie_stats[('Launched', 'Cmp')],
                "passes_attempted": goalie_stats[('Launched', 'Att')],
                "pass_accuracy": goalie_stats[('Launched', 'Cmp%')],
                "gk_passes_attempted": goalie_stats[('Passes', 'Att (GK)')],
                "throws": goalie_stats[('Passes', 'Thr')],
                "launch_percentage": goalie_stats[('Passes', 'Launch%')],
                "launch_average_length": goalie_stats[('Passes', 'AvgLen')],
                "goal_kicks_attempted": goalie_stats[('Goal Kicks', 'Att')],
                "goal_kick_launch_percentage": goalie_stats[('Goal Kicks', 'Launch%')],
                "goal_kick_average_length": goalie_stats[('Goal Kicks', 'AvgLen')],
                "crosses_opportunities": goalie_stats[('Crosses', 'Opp')],
                "crosses_stops": goalie_stats[('Crosses', 'Stp')],
                "crosses_stop_percentage": goalie_stats[('Crosses', 'Stp%')],
                "opa": goalie_stats[('Sweeper', '#OPA')],
                "opa_average_distance": goalie_stats[('Sweeper', 'AvgDist')],
            })

        # Add Away Team Goalie Stats
        for _, goalie_stats in away_team_goaly_stats.iterrows():
            session.run(goalie_query, {
                "goalie_name": goalie_stats[('Unnamed: 0_level_0', 'Player')],
                "nation": goalie_stats[('Unnamed: 1_level_0', 'Nation')],
                "age": goalie_stats[('Unnamed: 2_level_0', 'Age')],
                "match_id": match_id,
                "team_name": away_team_name,
                "minutes_played": goalie_stats[('Unnamed: 3_level_0', 'Min')],
                "sota": goalie_stats[('Shot Stopping', 'SoTA')],
                "goals_allowed": goalie_stats[('Shot Stopping', 'GA')],
                "saves": goalie_stats[('Shot Stopping', 'Saves')],
                "save_percentage": goalie_stats[('Shot Stopping', 'Save%')],
                "psxg": goalie_stats[('Shot Stopping', 'PSxG')],
                "passes_completed": goalie_stats[('Launched', 'Cmp')],
                "passes_attempted": goalie_stats[('Launched', 'Att')],
                "pass_accuracy": goalie_stats[('Launched', 'Cmp%')],
                "gk_passes_attempted": goalie_stats[('Passes', 'Att (GK)')],
                "throws": goalie_stats[('Passes', 'Thr')],
                "launch_percentage": goalie_stats[('Passes', 'Launch%')],
                "launch_average_length": goalie_stats[('Passes', 'AvgLen')],
                "goal_kicks_attempted": goalie_stats[('Goal Kicks', 'Att')],
                "goal_kick_launch_percentage": goalie_stats[('Goal Kicks', 'Launch%')],
                "goal_kick_average_length": goalie_stats[('Goal Kicks', 'AvgLen')],
                "crosses_opportunities": goalie_stats[('Crosses', 'Opp')],
                "crosses_stops": goalie_stats[('Crosses', 'Stp')],
                "crosses_stop_percentage": goalie_stats[('Crosses', 'Stp%')],
                "opa": goalie_stats[('Sweeper', '#OPA')],
                "opa_average_distance": goalie_stats[('Sweeper', 'AvgDist')],
            })
