# %%
from dotenv import load_dotenv, find_dotenv, dotenv_values
import os
load_dotenv(dotenv_path = os.path.join(os.getcwd(),'config/.env'))
# Out:
# True

# %%
from dotenv import load_dotenv, find_dotenv, dotenv_values
import os

# Dynamically find and load the .env file
env_path = os.path.join(os.getcwd(),'config/.env')
load_dotenv(dotenv_path=env_path)

# Print all environment variables from the loaded .env file
env_variables = dotenv_values(env_path)
for key, value in env_variables.items():
    print(f"{key} = {value}")

for k, v in to_insert.items():
    os.environ[k] = v
# Out:
# NEO4J_URI = neo4j+s://5fe6b298.databases.neo4j.io
# NEO4J_USERNAME = neo4j
# NEO4J_PASSWORD = V2S2unBr-ex60KUDHFzMH_KLkiPggGUR9UkEZYreAPM
# AURA_INSTANCEID = 5fe6b298
# AURA_INSTANCENAME = Instance01
