# %%
from dotenv import load_dotenv, find_dotenv

# %%
import os

# %%
load_dotenv(dotenv_path = os.path.join(os.getcwd(),'config/.env'))
# Out:
# True

# %%
os.getenv("NEO4J_URI")
# Out:
# 'neo4j+s://5fe6b298.databases.neo4j.io'

# %%
os.environ["NEO4J_"] = "1"
